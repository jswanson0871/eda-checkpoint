# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset: https://www.kaggle.com/datasets/aditya126/movies-box-office-dataset-2000-2024
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import numpy as np

#import csv as dataframe
df = pd.read_csv("/Users/jamesiaswanson/eda-checkpoint/box_office_data.csv")

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
#checking the first rows
df.head()

#checking the last rows 
df.tail()

#checking the dimension
df.shape

#checking for descriptives statisistics 
df.describe

#checking the columns
df.info()

#checking data types
df.dtypes

#checking for missing values 
df.isna().sum()

#checking for duplicates
df.duplicated().sum()

#checking for unique values 
df.nunique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  5000 non-null   int64
#  1   Release Group         5000 non-null   object
#  2   $Worldwide            5000 non-null   float64
#  3   $Domestic             5000 non-null   float64
#  4   Domestic %            5000 non-null   float64
#  5   $Foreign              5000 non-null   float64
#  6   Foreign %             5000 non-null   float64
#  7   Year                  5000 non-null   int64
#  8   Genres                4822 non-null   object
#  9   Rating                4830 non-null   object
#  10  Vote_Count            4830 non-null   float64
#  11  Original_Language     4830 non-null   object
#  12  Production_Countries  4800 non-null   object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 507.9+ KB
# ...

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
import matplotlib.pyplot as plt

movies_per_year = df['Year'].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.bar(movies_per_year.index, movies_per_year.values)
plt.title("Number of Movies Produced Each Year")
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.show()

import pandas as pd

# Count number of movies per year
movies_per_year = df['Year'].value_counts().sort_index()

print(movies_per_year)
# Out:
# Year
# 2000    200
# 2001    200
# 2002    200
# 2003    200
# 2004    200
# 2005    200
# 2006    200
# 2007    200
# 2008    200
# 2009    200
# 2010    200
# 2011    200
# 2012    200
# 2013    200
# 2014    200
# 2015    200
# 2016    200
# 2017    200
# 2018    200
# 2019    200
# 2020    200
# 2021    200
# 2022    200
# 2023    200
# 2024    200
# Name: count, dtype: int64

# %%
revenue_per_year = df.groupby('Year')['$Worldwide'].sum()

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(revenue_per_year.index, revenue_per_year.values, marker='o')
plt.title("Total Movie Revenue Per Year")
plt.xlabel("Year")
plt.ylabel("$Worldwide")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# I was surprised to see that there appears to be a cap on the number of movies listed each year. Depending on which films are included, this could affect results, especially when comparing revenue between domestic and foreign markets.
#
# 2. Do you have any concerns about your dataset?
# I am a bit concerned about the large decrease in revenue in 2020, as it might produce misleading or inaccurate results in the analysis.
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# There are some null values in the dataset that might affect my analysis, so I will need to address them during the data cleaning phase.
